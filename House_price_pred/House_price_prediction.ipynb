# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('kc_house_data.csv')

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.shape
# Out:
# (21613, 21)

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
data.describe()
# Out:
#                     id         price    bedrooms   bathrooms  sqft_living  \
# count      21613.00000   21613.00000 21613.00000 21613.00000  21613.00000
# mean  4580301520.86499  540088.14177     3.37084     2.11476   2079.89974
# std   2876565571.31206  367127.19648     0.93006     0.77016    918.44090
# min      1000102.00000   75000.00000     0.00000     0.00000    290.00000
# 25%   2123049194.00000  321950.00000     3.00000     1.75000   1427.00000
# 50%   3904930410.00000  450000.00000     3.00000     2.25000   1910.00000
# 75%   7308900445.00000  645000.00000     4.00000     2.50000   2550.00000
# max   9900000190.00000 7700000.00000    33.00000     8.00000  13540.00000
#
#            sqft_lot      floors  waterfront        view   condition  \
# count   21613.00000 21613.00000 21613.00000 21613.00000 21613.00000
# mean    15106.96757     1.49431     0.00754     0.23430     3.40943
# std     41420.51152     0.53999     0.08652     0.76632     0.65074
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sns.jointplot(x=data.lat.values, y=data.long.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()

# %%
sns.scatterplot(x=data.price,y=data.sqft_living)
plt.title("Price and Square Feet")
# Out:
# Text(0.5, 1.0, 'Price and Square Feet')

# %%
sns.scatterplot(x=data.price,y=data.long)
plt.title("Price and Location(area)")
# Out:
# Text(0.5, 1.0, 'Price and Location(area)')

# %%
sns.scatterplot(x=data.price,y=data.lat)
plt.title("Latitude and Price")
# Out:
# Text(0.5, 1.0, 'Latitude and Price')

# %% [markdown]
# # Splitting of Data for training and testing

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
X=data[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement',
        'sqft_living15', 'sqft_lot15']]

# %%
X
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3    1.00000         1180      5650 1.00000           0     0
# 1             3    2.25000         2570      7242 2.00000           0     0
# 2             2    1.00000          770     10000 1.00000           0     0
# 3             4    3.00000         1960      5000 1.00000           0     0
# 4             3    2.00000         1680      8080 1.00000           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3    2.50000         1530      1131 3.00000           0     0
# 21609         4    2.50000         2310      5813 2.00000           0     0
# 21610         2    0.75000         1020      1350 2.00000           0     0
# 21611         3    2.50000         1600      2388 2.00000           0     0
# 21612         2    0.75000         1020      1076 2.00000           0     0
#
# ...

# %%
Y=data['price']

# %%
Y
# Out:
# 0       221900.00000
# 1       538000.00000
# 2       180000.00000
# 3       604000.00000
# 4       510000.00000
#             ...
# 21608   360000.00000
# 21609   400000.00000
# 21610   402101.00000
# 21611   400000.00000
# 21612   325000.00000
# Name: price, Length: 21613, dtype: float64

# %%
#!pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test , Y_train , Y_test = train_test_split(X,Y,test_size=0.25,random_state=101)

# %%
X_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 19642         4    2.50000         2070      4270 2.00000           0     0
# 8626          3    2.25000         1400      6970 2.00000           0     0
# 6954          5    3.00000         2190      4900 2.00000           0     0
# 20242         4    2.50000         2547      4800 2.00000           0     0
# 10376         5    3.50000         4060      8309 2.00000           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 5695          3    2.25000         1920      9672 2.00000           0     0
# 8006          3    1.00000         1240      3600 1.50000           0     0
# 17745         3    2.25000         1780      7332 2.00000           0     0
# 17931         2    1.00000         1150      5000 1.00000           0     0
# 13151         3    1.00000         1450      7930 1.00000           0     0
#
# ...

# %%
Y_train
# Out:
# 19642   493000.00000
# 8626    425000.00000
# 6954    588000.00000
# 20242   392440.00000
# 10376   630000.00000
#             ...
# 5695    625000.00000
# 8006    390000.00000
# 17745   272450.00000
# 17931   552000.00000
# 13151   394000.00000
# Name: price, Length: 16209, dtype: float64

# %%
X_test
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 3834          2    1.00000         1050      6317 1.50000           0     0
# 1348          4    2.25000         2040      9565 1.00000           0     0
# 20366         4    2.50000         2500      4000 2.00000           0     0
# 16617         5    2.00000         2360     19899 1.00000           0     0
# 20925         3    3.00000         1670      4440 1.00000           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 7148          3    1.75000         1520      5500 1.50000           0     0
# 2747          5    3.00000         2970     10335 2.00000           0     0
# 15565         3    2.50000         3440    103672 2.00000           0     0
# 21238         3    2.50000         1572      4000 2.00000           0     0
# 2333          3    3.00000         2920     23085 1.50000           0     2
#
# ...

# %%
Y_test
# Out:
# 3834    349950.00000
# 1348    450000.00000
# 20366   635000.00000
# 16617   355500.00000
# 20925   246950.00000
#             ...
# 7148    738000.00000
# 2747    726000.00000
# 15565   560000.00000
# 21238   299000.00000
# 2333    555000.00000
# Name: price, Length: 5404, dtype: float64

# %% [markdown]
# # Normalization basically Standarization

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()

# %%
X_train_std=std.fit_transform(X_train)
X_test_std=std.transform(X_test)

# %%
X_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 19642         4    2.50000         2070      4270 2.00000           0     0
# 8626          3    2.25000         1400      6970 2.00000           0     0
# 6954          5    3.00000         2190      4900 2.00000           0     0
# 20242         4    2.50000         2547      4800 2.00000           0     0
# 10376         5    3.50000         4060      8309 2.00000           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 5695          3    2.25000         1920      9672 2.00000           0     0
# 8006          3    1.00000         1240      3600 1.50000           0     0
# 17745         3    2.25000         1780      7332 2.00000           0     0
# 17931         2    1.00000         1150      5000 1.00000           0     0
# 13151         3    1.00000         1450      7930 1.00000           0     0
#
# ...

# %%
X_train_std
# Out:
# array([[ 0.69608634,  0.49894508, -0.00810266, ..., -0.65896096,
#          0.12372791, -0.29371924],
#        [-0.40802008,  0.173745  , -0.74457445, ..., -0.65896096,
#         -0.27289927, -0.16524962],
#        [ 1.80019275,  1.14934525,  0.12380274, ...,  0.93301185,
#         -0.90456477, -0.29386481],
#        ...,
#        [-0.40802008,  0.173745  , -0.32687403, ..., -0.65896096,
#         -0.69890623, -0.18399236],
#        [-1.51212649, -1.45225542, -1.01937736, ..., -0.43153627,
#         -0.76794874, -0.3042734 ],
#        [-0.40802008, -1.45225542, -0.68961387, ...,  0.0233131 ,
#         -1.38933131, -0.17980708]])

# %%
X_test_std
# Out:
# array([[-1.51212649, -1.45225542, -1.12929852, ..., -0.65896096,
#         -0.56669717, -0.11153258],
#        [ 0.69608634,  0.173745  , -0.04107901, ...,  0.79655703,
#         -0.14069021, -0.14923641],
#        [ 0.69608634,  0.49894508,  0.46455834, ..., -0.65896096,
#         -0.74297592, -0.30500127],
#        ...,
#        [-0.40802008,  0.49894508,  1.49781727, ..., -0.65896096,
#          1.06388121,  3.64443868],
#        [-0.40802008,  0.49894508, -0.55551005, ..., -0.65896096,
#         -0.55494526, -0.27315682],
#        [-0.40802008,  1.14934525,  0.92622723, ...,  2.47949972,
#          0.41752581,  0.20014272]])

# %%
Y_train
# Out:
# 19642   493000.00000
# 8626    425000.00000
# 6954    588000.00000
# 20242   392440.00000
# 10376   630000.00000
#             ...
# 5695    625000.00000
# 8006    390000.00000
# 17745   272450.00000
# 17931   552000.00000
# 13151   394000.00000
# Name: price, Length: 16209, dtype: float64

# %%
Y_test
# Out:
# 3834    349950.00000
# 1348    450000.00000
# 20366   635000.00000
# 16617   355500.00000
# 20925   246950.00000
#             ...
# 7148    738000.00000
# 2747    726000.00000
# 15565   560000.00000
# 21238   299000.00000
# 2333    555000.00000
# Name: price, Length: 5404, dtype: float64

# %% [markdown]
# # Model training

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=lr.predict(X_test_std)

# %%
Y_pred
# Out:
# array([356776.02589275, 511927.33428643, 573736.52389151, ...,
#        824101.44697874, 437013.51415353, 731915.82170729])

# %%
Y_test
# Out:
# 3834    349950.00000
# 1348    450000.00000
# 20366   635000.00000
# 16617   355500.00000
# 20925   246950.00000
#             ...
# 7148    738000.00000
# 2747    726000.00000
# 15565   560000.00000
# 21238   299000.00000
# 2333    555000.00000
# Name: price, Length: 5404, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error,r2_score

# %%
mean_absolute_error(Y_test,Y_pred)
# Out:
# 151500.5360109019

# %%
X_test
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 3834          2    1.00000         1050      6317 1.50000           0     0
# 1348          4    2.25000         2040      9565 1.00000           0     0
# 20366         4    2.50000         2500      4000 2.00000           0     0
# 16617         5    2.00000         2360     19899 1.00000           0     0
# 20925         3    3.00000         1670      4440 1.00000           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 7148          3    1.75000         1520      5500 1.50000           0     0
# 2747          5    3.00000         2970     10335 2.00000           0     0
# 15565         3    2.50000         3440    103672 2.00000           0     0
# 21238         3    2.50000         1572      4000 2.00000           0     0
# 2333          3    3.00000         2920     23085 1.50000           0     2
#
# ...

# %%
X_test.loc[7148]
# Out:
# bedrooms           3.00000
# bathrooms          1.75000
# sqft_living     1520.00000
# sqft_lot        5500.00000
# floors             1.50000
# waterfront         0.00000
# view               0.00000
# condition          5.00000
# grade              7.00000
# sqft_above      1520.00000
# sqft_basement      0.00000
# sqft_living15   2310.00000
# sqft_lot15      5500.00000
# Name: 7148, dtype: float64

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.6211653492243892

# %% [markdown]
# # Lets predict for Single House

# %%
new_house=[[3,1,1520,5500,1.5,0,0,5,7,1520,0,2310,5500]]

# %%
new_house_std=std.transform(new_house)
# Out:
# C:\Users\PMYLS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_house_std
# Out:
# array([[-0.40802008, -1.45225542, -0.61266906, -0.22719555,  0.00725634,
#         -0.08921717, -0.30859645,  2.45576999, -0.55954731, -0.32544212,
#         -0.65896096,  0.47628539, -0.26132888]])

# %%
int(lr.predict(new_house_std))
# Out:
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_24528\2175366686.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   int(lr.predict(new_house_std))
# 478960
